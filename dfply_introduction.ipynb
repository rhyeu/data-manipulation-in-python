# %% [markdown]
# <a href="https://colab.research.google.com/github/rhyeu/data-manipulation-in-python/blob/main/dfply_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 작성일자 : 2021.02.02
# - 작성자 : 류성균

# %% [markdown]
# - reference : [dplyr-style Data Manipulation with Pipes in Python](https://towardsdatascience.com/dplyr-style-data-manipulation-with-pipes-in-python-380dcb137000)

# %%
# !pip install dfply

! pip install nycflights13
# Out:
# Collecting dfply
#   Downloading https://files.pythonhosted.org/packages/53/91/18ab48c64661252dadff685f8ddbc6f456302923918f488714ee2345d49b/dfply-0.3.3-py3-none-any.whl (612kB)
#      |████████████████████████████████| 614kB 5.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from dfply) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from dfply) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->dfply) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->dfply) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->dfply) (1.15.0)
# Installing collected packages: dfply
# Successfully installed dfply-0.3.3
# Collecting nycflights13
#   Downloading https://files.pythonhosted.org/packages/a1/6a/ce6fe2de399a54e1fc4c4b60c61987854974b936bab6d0f6444bc76939db/nycflights13-0.0.3.tar.gz (8.7MB)
#      |████████████████████████████████| 8.7MB 5.5MB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.6/dist-packages (from nycflights13) (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->nycflights13) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->nycflights13) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->nycflights13) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->nycflights13) (1.15.0)
# Building wheels for collected packages: nycflights13
#   Building wheel for nycflights13 (setup.py) ... done
#   Created wheel for nycflights13: filename=nycflights13-0.0.3-cp36-none-any.whl size=8732755 sha256=e080b238dec4f63047fbf2e7e9e480667bd9426780d1800a450a58950f3cd44b
#   Stored in directory: /root/.cache/pip/wheels/50/fe/ad/c6adafdf6e59183110670b4b14fb582c20b82a0fed449348cb
# Successfully built nycflights13
# Installing collected packages: nycflights13
# Successfully installed nycflights13-0.0.3

# %% [markdown]
# ### Getting started
# - 예제 데이터는 nycflights13 데이터 사용

# %%
from dfply import *
import pandas as pd

from nycflights13 import flights
# flights is the combined, tidied data, but can also import individual pieces..
from nycflights13 import airports

# %% [markdown]
# ### Data

# %%
flight_data = flights

flight_data.head()
# Out:
#    year  month  day  dep_time  ...  distance  hour  minute             time_hour
# 0  2013      1    1     517.0  ...      1400     5      15  2013-01-01T10:00:00Z
# 1  2013      1    1     533.0  ...      1416     5      29  2013-01-01T10:00:00Z
# 2  2013      1    1     542.0  ...      1089     5      40  2013-01-01T10:00:00Z
# 3  2013      1    1     544.0  ...      1576     5      45  2013-01-01T10:00:00Z
# 4  2013      1    1     554.0  ...       762     6       0  2013-01-01T11:00:00Z
#
# [5 rows x 19 columns]

# %% [markdown]
# ### Piping

# %% [markdown]
# ### 'original_data' could be a pandas DataFrame.
# - `pandas` 형테의 전처리
# ```
# result_1 = transformation_1(original_data, *args, **kwargs)
# result_2 = transformation_2(result_1, *args, **kwargs)
# result_3 = transformation_3(result_2, *args, **kwargs)
# .
# .
# .
# final_result = transformation_n(result_n-1, *args, **kwargs)
# ```

# %% [markdown]
# - `pipe` 연산자를 통해 코드가 깔끔해짐 (ex - `R`의 `dplyr` `%>%`연산자
#
# ```
# final_result = original_data -->
#                 transformation_1(*args, **kwargs) -->
#                 transformation_2(*args, **kwargs) -->
#                 transformation_3(*args, **kwargs) -->
#                 .
#                 .
#                 .
#                 transformation_n(*args, **kwargs)
# ```
# - `dfply` 패키지
#     - 에서는 `>>` 연산자를 사용
#     - 상속하는 컬럼에서는 `X.`를 붙여서 어느 데이터프레임의 컬럼인지를 표시하게끔 함
#
# ```
# # 'data' is the original pandas DataFrame
# (data >>
#  select(X.first_col, X.second_col, X.third_col) >>
#  drop(X.third_col) >>
#  head(3))
#  ```

# %% [markdown]
# ### Exploring some of dfply’s transformation methods
#
# - selecting and dropping columns
# - subsetting and filtering rows
# - grouping data
# - reshaping data
# - to name a few

# %% [markdown]
# #### Select and drop columns with `select()` and `drop()`
#
# - 컬럼을 선택하려면 `select`
# - 컬럼을 제외하려면 `drop` 혹은 `select + ~`m

# %%
(flight_data >> 
    select(X.origin, X.dest, X.hour))
# Out:
#        origin dest  hour
# 0         EWR  IAH     5
# 1         LGA  IAH     5
# 2         JFK  MIA     5
# 3         JFK  BQN     5
# 4         LGA  ATL     6
# ...       ...  ...   ...
# 336771    JFK  DCA    14
# 336772    LGA  SYR    22
# 336773    LGA  BNA    12
# 336774    LGA  CLE    11
# 336775    LGA  RDU     8
#
# [336776 rows x 3 columns]

# %%
(flight_data >>
    drop(X.year, X.month, X.day))
# Out:
#         dep_time  sched_dep_time  dep_delay  ...  hour  minute             time_hour
# 0          517.0             515        2.0  ...     5      15  2013-01-01T10:00:00Z
# 1          533.0             529        4.0  ...     5      29  2013-01-01T10:00:00Z
# 2          542.0             540        2.0  ...     5      40  2013-01-01T10:00:00Z
# 3          544.0             545       -1.0  ...     5      45  2013-01-01T10:00:00Z
# 4          554.0             600       -6.0  ...     6       0  2013-01-01T11:00:00Z
# ...          ...             ...        ...  ...   ...     ...                   ...
# 336771       NaN            1455        NaN  ...    14      55  2013-09-30T18:00:00Z
# 336772       NaN            2200        NaN  ...    22       0  2013-10-01T02:00:00Z
# 336773       NaN            1210        NaN  ...    12      10  2013-09-30T16:00:00Z
# 336774       NaN            1159        NaN  ...    11      59  2013-09-30T15:00:00Z
# 336775       NaN             840        NaN  ...     8      40  2013-09-30T12:00:00Z
#
# [336776 rows x 16 columns]

# %%
(flight_data >>
    select(~X.hour, ~X.minute))
# Out:
#         year  month  day  ...  air_time  distance             time_hour
# 0       2013      1    1  ...     227.0      1400  2013-01-01T10:00:00Z
# 1       2013      1    1  ...     227.0      1416  2013-01-01T10:00:00Z
# 2       2013      1    1  ...     160.0      1089  2013-01-01T10:00:00Z
# 3       2013      1    1  ...     183.0      1576  2013-01-01T10:00:00Z
# 4       2013      1    1  ...     116.0       762  2013-01-01T11:00:00Z
# ...      ...    ...  ...  ...       ...       ...                   ...
# 336771  2013      9   30  ...       NaN       213  2013-09-30T18:00:00Z
# 336772  2013      9   30  ...       NaN       198  2013-10-01T02:00:00Z
# 336773  2013      9   30  ...       NaN       764  2013-09-30T16:00:00Z
# 336774  2013      9   30  ...       NaN       419  2013-09-30T15:00:00Z
# 336775  2013      9   30  ...       NaN       431  2013-09-30T12:00:00Z
#
# [336776 rows x 17 columns]

# %% [markdown]
# #### Filter rows with mask()

# %%
(flight_data >>
    mask(X.month == 1, X.day == 1, X.origin == 'JFK', X.hour > 10))
# Out:
#      year  month  day  dep_time  ...  distance  hour  minute             time_hour
# 151  2013      1    1     848.0  ...       184    18      35  2013-01-01T23:00:00Z
# 258  2013      1    1    1059.0  ...       213    11       0  2013-01-01T16:00:00Z
# 265  2013      1    1    1111.0  ...       266    11      15  2013-01-01T16:00:00Z
# 266  2013      1    1    1112.0  ...      2586    11       0  2013-01-01T16:00:00Z
# 272  2013      1    1    1124.0  ...      2586    11       0  2013-01-01T16:00:00Z
# ..    ...    ...  ...       ...  ...       ...   ...     ...                   ...
# 832  2013      1    1    2326.0  ...      2248    21      30  2013-01-02T02:00:00Z
# 833  2013      1    1    2327.0  ...       209    22      50  2013-01-02T03:00:00Z
# 835  2013      1    1    2353.0  ...      1617    23      59  2013-01-02T04:00:00Z
# 836  2013      1    1    2353.0  ...      1598    23      59  2013-01-02T04:00:00Z
# 837  2013      1    1    2356.0  ...      1576    23      59  2013-01-02T04:00:00Z
#
# [213 rows x 19 columns]

# %% [markdown]
# #### Sort rows with `arrange()`
# - 역순으로 할 때는 `ascending = False` argument 사용

# %%
(flight_data >> 
    arrange(X.distance, X.hour, ascemnding = [False, True]))
# Out:
#         year  month  day  ...  hour  minute             time_hour
# 162     2013      1    1  ...     9       0  2013-01-01T14:00:00Z
# 1073    2013      1    2  ...     9       0  2013-01-02T14:00:00Z
# 2018    2013      1    3  ...     9       0  2013-01-03T14:00:00Z
# 2922    2013      1    4  ...     9       0  2013-01-04T14:00:00Z
# 3791    2013      1    5  ...     9       0  2013-01-05T14:00:00Z
# ...      ...    ...  ...  ...   ...     ...                   ...
# 117903  2013      2    8  ...    21      29  2013-02-09T02:00:00Z
# 119764  2013      2   10  ...    21      29  2013-02-11T02:00:00Z
# 120660  2013      2   11  ...    21      29  2013-02-12T02:00:00Z
# 121615  2013      2   12  ...    21      30  2013-02-13T02:00:00Z
# 275945  2013      7   27  ...     1       6  2013-07-27T05:00:00Z
#
# [336776 rows x 19 columns]

# %% [markdown]
# #### Add new columns with `mutate()`

# %%
(flight_data >>
    mutate(
        new_distance = X.distance / 1000,
        carrier_origin = X.carrier + X.origin
    ) >>
    select(["new_distance", "carrier_origin"]))
# Out:
#         new_distance carrier_origin
# 0              1.400          UAEWR
# 1              1.416          UALGA
# 2              1.089          AAJFK
# 3              1.576          B6JFK
# 4              0.762          DLLGA
# ...              ...            ...
# 336771         0.213          9EJFK
# 336772         0.198          9ELGA
# 336773         0.764          MQLGA
# 336774         0.419          MQLGA
# 336775         0.431          MQLGA
#
# [336776 rows x 2 columns]

# %% [markdown]
# ### Group and ungroup data with `group_by()` and `ungroup()`

# %%
(flight_data >>
    group_by(X.origin)
)

# %% [markdown]
# #### Sumarise data using `summarize()`

# %%
(flight_data >>
 group_by(X.origin) >>
 summarize(mean_distance = X.distance.mean())
)
# Out:
#   origin  mean_distance
# 0    EWR    1056.742790
# 1    JFK    1266.249077
# 2    LGA     779.835671

# %% [markdown]
# #### 예제 : Bringing it all together with pipes
# - [Step 1]: Filter out all flights less than 10 hours
# - [Step 2]: Create a new column, speed, using the formula [distance / (air time * 60)]
# - [Step 3]: Calculate the mean speed for flights originating from each airport
# - [Step 4]: Sort the result by mean speed in descending order

# %%
flight_data.head()
# Out:
#    year  month  day  dep_time  ...  distance  hour  minute             time_hour
# 0  2013      1    1     517.0  ...      1400     5      15  2013-01-01T10:00:00Z
# 1  2013      1    1     533.0  ...      1416     5      29  2013-01-01T10:00:00Z
# 2  2013      1    1     542.0  ...      1089     5      40  2013-01-01T10:00:00Z
# 3  2013      1    1     544.0  ...      1576     5      45  2013-01-01T10:00:00Z
# 4  2013      1    1     554.0  ...       762     6       0  2013-01-01T11:00:00Z
#
# [5 rows x 19 columns]

# %%
### pandas version
flight_data.loc[flight_data['hour']>10, 'speed'] = flight_data['distance'] / (flight_data['air_time'] * 60)
result = flight_data.groupby('origin', as_index = False)['speed'].mean()

result.sort_values('speed', ascending = False)
# Out:
#   origin     speed
# 0    EWR  0.109777
# 1    JFK  0.109427
# 2    LGA  0.107362

# %%
### dfply version
(flight_data >>
    mask(X.hour > 10) >>
    mutate(speed = X.distance / (X.air_time * 60)) >>
    group_by(X.origin) >>
    summarise(mean_speed = mean(X.speed)) >>
    arrange(X.mean_speed, ascending = False)
)
# Out:
#   origin  mean_speed
# 0    EWR    0.109777
# 1    JFK    0.109427
# 2    LGA    0.107362
